# %% [markdown]
# ### Lahore Air Quality & Smog Forecast
# #### Notebook 2: Feature Engineering
#
# Purpose: Prepare the cleaned daily dataset for machine learning by:
#
# *   creating prediction targets,
# *   generating lag features from historical PM2.5 values,
# * calculating rolling average features,
# * preserving the chronological order of observations for each monitoring station,
# * and producing a feature-rich dataset ready for model training.

# %%
import pandas as pd
import numpy as np

# %%
daily_df = pd.read_csv("lahore_air_quality_cleaned.csv")

print(daily_df.shape)
daily_df.head()
# Out:
# (15881, 11)
#                           name        date        pm25  temperature  \
# 0  AC OFFICE NISHTAR, GAJUMATA  2025-11-20  221.500000    21.650000
# 1  AC OFFICE NISHTAR, GAJUMATA  2025-11-21  338.000000    18.150000
# 2  AC OFFICE NISHTAR, GAJUMATA  2025-11-23  308.000000    15.050000
# 3                  ARC, Lahore  2025-11-10  267.000000    17.669231
# 4                  ARC, Lahore  2025-11-11  267.708333    18.341667
#
#    relativehumidity  wind_speed  wind_direction        lat        lon  \
# 0         57.000000    3.650000          20.500  31.377378  74.350574
# 1         70.000000    3.200000         218.500  31.377378  74.350574
# 2         73.000000    3.050000         328.000  31.377378  74.350574
# 3         66.076923    1.215385         147.000  31.522056  74.314944
# 4         64.875000    3.308333         208.625  31.522056  74.314944
#
#    location_id  is_smog_season
# 0      6135476               1
# 1      6135476               1
# 2      6135476               1
# 3      6125629               1
# 4      6125629               1

# %%
daily_df["date"] = pd.to_datetime(daily_df["date"])

# %%
daily_df = daily_df.sort_values(["name", "date"]).reset_index(drop=True)

# %%
daily_df["pm25_day1"] = daily_df.groupby("name")["pm25"].shift(-1)
daily_df["pm25_day2"] = daily_df.groupby("name")["pm25"].shift(-2)
daily_df["pm25_day3"] = daily_df.groupby("name")["pm25"].shift(-3)

# %%
daily_df = daily_df.dropna().reset_index(drop=True)

# %%
print(daily_df.shape)
daily_df.head()
# Out:
# (15657, 14)
#           name       date        pm25  temperature  relativehumidity  \
# 0  ARC, Lahore 2025-11-10  267.000000    17.669231         66.076923
# 1  ARC, Lahore 2025-11-11  267.708333    18.341667         64.875000
# 2  ARC, Lahore 2025-11-12  265.611111    16.227778         68.888889
# 3  ARC, Lahore 2025-11-13  234.470588    16.564706         64.764706
# 4  ARC, Lahore 2025-11-14  322.333333    15.166667         73.866667
#
#    wind_speed  wind_direction        lat        lon  location_id  \
# 0    1.215385      147.000000  31.522056  74.314944      6125629
# 1    3.308333      208.625000  31.522056  74.314944      6125629
# 2    3.638889      296.000000  31.522056  74.314944      6125629
# 3    3.605882      293.764706  31.522056  74.314944      6125629
# 4    1.386667      192.466667  31.522056  74.314944      6125629
#
#    is_smog_season   pm25_day1   pm25_day2   pm25_day3
# 0               1  267.708333  265.611111  234.470588
# 1               1  265.611111  234.470588  322.333333
# 2               1  234.470588  322.333333  270.125000
# 3               1  322.333333  270.125000  231.878261
# 4               1  270.125000  231.878261  283.727273

# %%
stations = sorted(daily_df["name"].unique())
print(stations)
# Out:
# ['ARC, Lahore', 'Abdullah Khokhar, House Johar Town', 'Allama Iqbal Town B LHE', 'Askari 10', 'Assistant Commissioner Office, Allama Iqbal ', 'B Block, Phase 5, DHA', 'BAM,  Civil Secretariat', 'Bahria Town ', 'Barki, Lahore', 'Bedian Thethar Rd LHE', 'Burki Rd B LHE', 'CERP Office', 'Cantonment', 'Civil Secretariat', 'Climate Finance Pakistan (PakAirQuality)', 'College Road', 'Diamond Paint industries PVT LTD.', 'FF Pakistan', 'FF Pakistan - 1', 'FOOT & MOUTH DISEASE RESEARCH CENTRE', 'Ferozepur Rd A LHE', 'Forman Christian College & Chartered University', 'GENERATION Pvt ltd', 'Gajju Matta (Kahna)', 'Ghazi Road Interchange', 'Grand Charter School', 'Gulberg III', 'Gurumangat Rd B LHE', 'HBFC Society, DHA Phase 5 (Hussainy House)', 'HC - Askari 10', 'Hiking & Mountaineering Club GCU Lahore', 'Honda Gateway', 'IEEE, Punjab University, LHR', 'Johar Town', 'Johar Town B LHE', 'Kahna Hospital ', 'Kickstart MM Alam', 'LAS Lahore', 'Lahore', 'Learning Alliance Intl. DHA', 'Model Town', 'Model Town A LHE', 'Model Town B LHE', 'Model Town, CD Ground', 'NPPMCL', 'Near Ada Plot, Raiwind Road', 'Pajian, Raiwind', 'Pak Arab', 'Pakistan Engineering Services (Pvt) Ltd.', 'Phase8-DHA', 'Powerzone head office', 'Ravi Road', 'Revenue Employees Coop Housing Society', 'SOS Johar Town LHR', 'Samanabad', 'Sandha Road', 'Scarsdale International School', 'Shadman Market B LHE', 'Shalimar Town', 'Syed Maratib Ali Road', 'The Bank of Punjab, Head Office, BOP Tower, Gulberg III.', 'The University of Lahore', 'Thokar Niaz Baig', 'Trinity School Lahore', 'Tufail Road near Rahat Bakery', 'US Diplomatic Post: Lahore', 'University of Central Punjab', 'University of Management and Technology', 'VTS', 'Valancia Town Lahore', 'W.R', 'WWF-PAKISTAN', 'Yani Home']

# %%
daily_df.to_csv("lahore_air_quality_features.csv", index=False)

# %% [markdown]
# ### Reflection
#
# In this notebook, I transformed the cleaned daily air quality dataset into a machine learning dataset by creating prediction targets for one-, two-, and three-day PM2.5 forecasts. I also engineered lag features and a seven-day rolling average to capture recent pollution trends while preserving the chronological order of observations for each monitoring station. The resulting dataset is ready for training forecasting models in the next notebook.
